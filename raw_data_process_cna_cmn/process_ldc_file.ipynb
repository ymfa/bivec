# %%
import os
import sys
import re
from xml.etree import cElementTree as ET

import logging
if sys.argv[0]=='/opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py':
    logging.basicConfig(level=logging.DEBUG)
    prefix='ldc'
    logging.debug('prefix is {0}'.format(prefix))
    root='./cna_cmn'
    trad_out='./{0}.tc'.format(prefix)
else:
    logging.basicConfig(filename='extract_test_case.log',level=logging.DEBUG)

    
if len(sys.argv)<3:
    logging.warning ('root outfile missing')
    root='./cna_cmn'
    trad_out='./ldc.tc'
    logging.warning ('switched to default. root={0}, trad_out={1}'.format(root,trad_out))

else:
    root=sys.argv[1]
    trad_out=sys.argv[2]+'.tc'
# Out:
# DEBUG:root:prefix is ldc

# %%
def process_sent(sent,seg=False):
    sent_out=[]
    sent=sent.strip()
    
    sent=sent.replace('\n','')
    if seg==True:
        sent_list=re.findall(r'[^！。？!?\n]+(?:[！。？!?\n])*', sent)
    else:
        sent_list=[sent]
    sent_out=["%s\n" % l for l in sent_list]
    return sent_out

def parse_single_xml(xml_f,outf):
    seg=True
    tree = ET.parse(xml_f)
    root = tree.getroot()
    for DOC in root:

         if DOC.attrib['type'] in ['multi','story']:
            for child in DOC:
                if child.tag not in ['HEADLINE','TEXT']:
                    continue
                lines=[]
                if child.tag =='HEADLINE':
                    if child.text!='':
                        lines+=process_sent(child.text)
                elif child.tag=='TEXT':
                     TEXT=child
                     
                     if len(TEXT)>0:
                            for p in TEXT:
                                if p.text!='':
                                    lines+= process_sent(p.text,seg)
                     else:
                        if TEXT.text!='':
                            lines+=process_sent(TEXT.text,seg)
                if lines!=[]:
                    outf.writelines(lines)

# %%
with open(trad_out,'w') as outf:
        for rt, dirs, files in os.walk(root):


            for file in files:
                 if file.startswith('cna_cmn'):
                    filepath=root+'/'+file
                    print (filepath)
                    parse_single_xml(filepath,outf)
# Out:
# ./cna_cmn/cna_cmn_199402
# ./cna_cmn/cna_cmn_200303
# ./cna_cmn/cna_cmn_200409
# ./cna_cmn/cna_cmn_199711
# ./cna_cmn/cna_cmn_199912
# ./cna_cmn/cna_cmn_199303
# ./cna_cmn/cna_cmn_199211
# ./cna_cmn/cna_cmn_199610
# ./cna_cmn/cna_cmn_199801
# ./cna_cmn/cna_cmn_199704
# ./cna_cmn/cna_cmn_200508
# ./cna_cmn/cna_cmn_200104
# ./cna_cmn/cna_cmn_200905
# ./cna_cmn/cna_cmn_199911
# ./cna_cmn/cna_cmn_200709
# ./cna_cmn/cna_cmn_199608
# ./cna_cmn/cna_cmn_199209
# ./cna_cmn/cna_cmn_200607
# ./cna_cmn/cna_cmn_200207
# ./cna_cmn/cna_cmn_200603
# ./cna_cmn/cna_cmn_200205
# ./cna_cmn/cna_cmn_199406
# ./cna_cmn/cna_cmn_201001
# ./cna_cmn/cna_cmn_200908
# ./cna_cmn/cna_cmn_199202
# ./cna_cmn/cna_cmn_199102
# ./cna_cmn/cna_cmn_200903
# ./cna_cmn/cna_cmn_199204
# ./cna_cmn/cna_cmn_199907
# ./cna_cmn/cna_cmn_200804
# ./cna_cmn/cna_cmn_199401
# ./cna_cmn/cna_cmn_199902
# ./cna_cmn/cna_cmn_199507
# ./cna_cmn/cna_cmn_199812
# ./cna_cmn/cna_cmn_200802
# ./cna_cmn/cna_cmn_200404
# ./cna_cmn/cna_cmn_200310
# ./cna_cmn/cna_cmn_200711
# ./cna_cmn/cna_cmn_199901
# ./cna_cmn/cna_cmn_200707
# ./cna_cmn/cna_cmn_200811
# ./cna_cmn/cna_cmn_199203
# ./cna_cmn/cna_cmn_199405
# ./cna_cmn/cna_cmn_200302
# ./cna_cmn/cna_cmn_199606
# ./cna_cmn/cna_cmn_200201
# ./cna_cmn/cna_cmn_200106
# ./cna_cmn/cna_cmn_201011
# ./cna_cmn/cna_cmn_199607
# ./cna_cmn/cna_cmn_200906
# ./cna_cmn/cna_cmn_200809
# ./cna_cmn/cna_cmn_200808
# ./cna_cmn/cna_cmn_200812
# ./cna_cmn/cna_cmn_200512
# ./cna_cmn/cna_cmn_200006
# ./cna_cmn/cna_cmn_200412
# ./cna_cmn/cna_cmn_199504
# ./cna_cmn/cna_cmn_200209
# ./cna_cmn/cna_cmn_199702
# ./cna_cmn/cna_cmn_200803
# ./cna_cmn/cna_cmn_200411
# ./cna_cmn/cna_cmn_200909
# ./cna_cmn/cna_cmn_200511
# ./cna_cmn/cna_cmn_199803
# ./cna_cmn/cna_cmn_199109
# ./cna_cmn/cna_cmn_199707
# ./cna_cmn/cna_cmn_199304
# ./cna_cmn/cna_cmn_199506
# ./cna_cmn/cna_cmn_199701
# ./cna_cmn/cna_cmn_201009
# ./cna_cmn/cna_cmn_199408
# ./cna_cmn/cna_cmn_200701
# ./cna_cmn/cna_cmn_199604
# ./cna_cmn/cna_cmn_199312
# ./cna_cmn/cna_cmn_200807
# ./cna_cmn/cna_cmn_199509
# ./cna_cmn/cna_cmn_199501
# ./cna_cmn/cna_cmn_199609
# ./cna_cmn/cna_cmn_200501
# ./cna_cmn/cna_cmn_199612
# ./cna_cmn/cna_cmn_199806
# ./cna_cmn/cna_cmn_199804
# ./cna_cmn/cna_cmn_199112
# ./cna_cmn/cna_cmn_200503
# ./cna_cmn/cna_cmn_200507
# ./cna_cmn/cna_cmn_199603
# ./cna_cmn/cna_cmn_200212
# ./cna_cmn/cna_cmn_199808
# ./cna_cmn/cna_cmn_199409
# ./cna_cmn/cna_cmn_200509
# ./cna_cmn/cna_cmn_199511
# ./cna_cmn/cna_cmn_200107
# ./cna_cmn/cna_cmn_199412
# ./cna_cmn/cna_cmn_200910
# ./cna_cmn/cna_cmn_200210
# ./cna_cmn/cna_cmn_199309
# ./cna_cmn/cna_cmn_199210
# ./cna_cmn/cna_cmn_199308
# ./cna_cmn/cna_cmn_199909
# ./cna_cmn/cna_cmn_200911
# ./cna_cmn/cna_cmn_201007
# ./cna_cmn/cna_cmn_201008
# ./cna_cmn/cna_cmn_200203
# ./cna_cmn/cna_cmn_200105
# ./cna_cmn/cna_cmn_200301
# ./cna_cmn/cna_cmn_199601
# ./cna_cmn/cna_cmn_199502
# ./cna_cmn/cna_cmn_200311
# ./cna_cmn/cna_cmn_200102
# ./cna_cmn/cna_cmn_200005
# ./cna_cmn/cna_cmn_199611
# ./cna_cmn/cna_cmn_201010
# ./cna_cmn/cna_cmn_200312
# ./cna_cmn/cna_cmn_200805
# ./cna_cmn/cna_cmn_199605
# ./cna_cmn/cna_cmn_199905
# ./cna_cmn/cna_cmn_200706
# ./cna_cmn/cna_cmn_201006
# ./cna_cmn/cna_cmn_200612
# ./cna_cmn/cna_cmn_199906
# ./cna_cmn/cna_cmn_201012
# ./cna_cmn/cna_cmn_200309
# ./cna_cmn/cna_cmn_200403
# ./cna_cmn/cna_cmn_200506
# ./cna_cmn/cna_cmn_200712
# ./cna_cmn/cna_cmn_199410
# ./cna_cmn/cna_cmn_201002
# ./cna_cmn/cna_cmn_200502
# ./cna_cmn/cna_cmn_199207
# ./cna_cmn/cna_cmn_200912
# ./cna_cmn/cna_cmn_200806
# ./cna_cmn/cna_cmn_199802
# ./cna_cmn/cna_cmn_199306
# ./cna_cmn/cna_cmn_199111
# ./cna_cmn/cna_cmn_200704
# ./cna_cmn/cna_cmn_200510
# ./cna_cmn/cna_cmn_199807
# ./cna_cmn/cna_cmn_200901
# ./cna_cmn/cna_cmn_199206
# ./cna_cmn/cna_cmn_199104
# ./cna_cmn/cna_cmn_199602
# ./cna_cmn/cna_cmn_200101
# ./cna_cmn/cna_cmn_200902
# ./cna_cmn/cna_cmn_200703
# ./cna_cmn/cna_cmn_199904
# ./cna_cmn/cna_cmn_200109
# ./cna_cmn/cna_cmn_200604
# ./cna_cmn/cna_cmn_201004
# ./cna_cmn/cna_cmn_199706
# ./cna_cmn/cna_cmn_200504
# ./cna_cmn/cna_cmn_200010
# ./cna_cmn/cna_cmn_199105
# ./cna_cmn/cna_cmn_200602
# ./cna_cmn/cna_cmn_200003
# ./cna_cmn/cna_cmn_200402
# ./cna_cmn/cna_cmn_199212
# ./cna_cmn/cna_cmn_199910
# ./cna_cmn/cna_cmn_199305
# ./cna_cmn/cna_cmn_200606
# ./cna_cmn/cna_cmn_200408
# ./cna_cmn/cna_cmn_200410
# ./cna_cmn/cna_cmn_200011
# ./cna_cmn/cna_cmn_199505
# ./cna_cmn/cna_cmn_201005
# ./cna_cmn/cna_cmn_199810
# ./cna_cmn/cna_cmn_200108
# ./cna_cmn/cna_cmn_200401
# ./cna_cmn/cna_cmn_200308
# ./cna_cmn/cna_cmn_200904
# ./cna_cmn/cna_cmn_200110
# ./cna_cmn/cna_cmn_199205
# ./cna_cmn/cna_cmn_200405
# ./cna_cmn/cna_cmn_199708
# ./cna_cmn/cna_cmn_199404
# ./cna_cmn/cna_cmn_200204
# ./cna_cmn/cna_cmn_199903
# ./cna_cmn/cna_cmn_199108
# ./cna_cmn/cna_cmn_199710
# ./cna_cmn/cna_cmn_199510
# ./cna_cmn/cna_cmn_199107
# ./cna_cmn/cna_cmn_200004
# ./cna_cmn/cna_cmn_199712
# ./cna_cmn/cna_cmn_199411
# ./cna_cmn/cna_cmn_200810
# ./cna_cmn/cna_cmn_201003
# ./cna_cmn/cna_cmn_200008
# ./cna_cmn/cna_cmn_200708
# ./cna_cmn/cna_cmn_199110
# ./cna_cmn/cna_cmn_200907
# ./cna_cmn/cna_cmn_200202
# ./cna_cmn/cna_cmn_199307
# ./cna_cmn/cna_cmn_199310
# ./cna_cmn/cna_cmn_200702
# ./cna_cmn/cna_cmn_199403
# ./cna_cmn/cna_cmn_200601
# ./cna_cmn/cna_cmn_199811
# ./cna_cmn/cna_cmn_199709
# ./cna_cmn/cna_cmn_200705
# ./cna_cmn/cna_cmn_200306
# ./cna_cmn/cna_cmn_199301
# ./cna_cmn/cna_cmn_199208
# ./cna_cmn/cna_cmn_199908
# ./cna_cmn/cna_cmn_199311
# ./cna_cmn/cna_cmn_199805
# ./cna_cmn/cna_cmn_200012
# ./cna_cmn/cna_cmn_200111
# ./cna_cmn/cna_cmn_199503
# ./cna_cmn/cna_cmn_200103
# ./cna_cmn/cna_cmn_200009
# ./cna_cmn/cna_cmn_199508
# ./cna_cmn/cna_cmn_199101
# ./cna_cmn/cna_cmn_199809
# ./cna_cmn/cna_cmn_200406
# ./cna_cmn/cna_cmn_199705
# ./cna_cmn/cna_cmn_200001
# ./cna_cmn/cna_cmn_200710
# ./cna_cmn/cna_cmn_200208
# ./cna_cmn/cna_cmn_199302
# ./cna_cmn/cna_cmn_200307
# ./cna_cmn/cna_cmn_200605
# ./cna_cmn/cna_cmn_200305
# ./cna_cmn/cna_cmn_200801
# ./cna_cmn/cna_cmn_200407
# ./cna_cmn/cna_cmn_199512
# ./cna_cmn/cna_cmn_200002
# ./cna_cmn/cna_cmn_199103
# ./cna_cmn/cna_cmn_199106
# ./cna_cmn/cna_cmn_200505
# ./cna_cmn/cna_cmn_200211
# ./cna_cmn/cna_cmn_200304
# ./cna_cmn/cna_cmn_200007
# ./cna_cmn/cna_cmn_199201
# ./cna_cmn/cna_cmn_199407
# ./cna_cmn/cna_cmn_200112
# ./cna_cmn/cna_cmn_199703
# ./cna_cmn/cna_cmn_200206

# %%
# line_out=''
# for root, dirs, files in os.walk(root):
    
     
#     for file in files:
#      if file.startswith('cna_cmn_'):
#        print (file)
#        num=0
#        try:
#         with open(file) as f:
#          for line in f:
#             #print (num)
#             line=line.strip()
#             if line.startswith('<') and line.endswith('>'):
               
#                if line_out!='':
                   
#                     sents=re.findall(r'[^！。？!?\n]+(?:[！。？!?\n])*', line_out)
                    
#                     outf.writelines("%s\n" % l for l in sents)
#                line_out=''
#                continue
#             else:
                
#                 #print (line)
#                 line_out+=line
                
        
#          num+=1
#        except:
#         print (file) 
#         print (num)
# outf.close()
